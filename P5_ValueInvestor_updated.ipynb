# %% [markdown]
# <a href="https://colab.research.google.com/github/alyhussein86/C6oUVdljHlRZgnaq/blob/main/P5_ValueInvestor_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
from prophet import Prophet
import numpy as np
import matplotlib.pyplot as plt
from prophet.plot import plot_plotly, plot_components_plotly
from pandas import DataFrame, to_datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from datetime import timedelta, datetime
import holidays
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from math import sqrt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Importing Dataframe

# %%
# Provide the path to your Excel file
excel_file_path = '/content/2020Q1Q2Q3Q4-2021Q1.xlsx'

# Read the Excel sheet into a pandas DataFrame
df = pd.read_excel(excel_file_path,'Russia - Sberbank Rossii PAO (S')
# df =  pd.read_excel(excel_file_path,'Turkey - Koc Holding AS (KCHOL)')

# %%
df = df.iloc[:-1,:2]
print(df)
# Out:
#                     Date   Price
# 0    2020-01-03 00:00:00     255
# 1    2020-01-06 00:00:00   253.9
# 2    2020-01-08 00:00:00  259.15
# 3    2020-01-09 00:00:00  257.99
# 4    2020-01-10 00:00:00  258.19
# ..                   ...     ...
# 306  2021-03-25 00:00:00  286.66
# 307  2021-03-26 00:00:00  291.22
# 308  2021-03-29 00:00:00   293.3
# 309  2021-03-30 00:00:00  293.25
# 310  2021-03-31 00:00:00  291.02
#
# [311 rows x 2 columns]

# %%
# Filtering DF before the Q1 of second year
specific_date_str = "2020-12-31"
specific_date = pd.to_datetime(specific_date_str)

filtered_df = df[df['Date'] <= specific_date]

# %%
filtered_df.rename(columns={'Date': 'ds', 'Price': 'y'}, inplace=True)
# Out:
# <ipython-input-5-52fe866b4294>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.rename(columns={'Date': 'ds', 'Price': 'y'}, inplace=True)

# %%
# Convert the 'date' column to datetime objects
filtered_df['ds'] = pd.to_datetime(filtered_df['ds'])
# Out:
# <ipython-input-6-a27fe6d10871>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['ds'] = pd.to_datetime(filtered_df['ds'])

# %%
print(filtered_df)
# Out:
#             ds       y
# 0   2020-01-03     255
# 1   2020-01-06   253.9
# 2   2020-01-08  259.15
# 3   2020-01-09  257.99
# 4   2020-01-10  258.19
# ..         ...     ...
# 245 2020-12-24  269.32
# 246 2020-12-25  270.64
# 247 2020-12-28   274.7
# 248 2020-12-29     272
# 249 2020-12-30  271.65
#
# [250 rows x 2 columns]

# %%
df_Test = df[df['Date'] > specific_date]

# %%
df_Test
# Out:
#                     Date   Price
# 250  2021-01-04 00:00:00     272
# 251  2021-01-05 00:00:00   275.2
# 252  2021-01-06 00:00:00  272.93
# 253  2021-01-08 00:00:00  283.64
# 254  2021-01-11 00:00:00  289.49
# ..                   ...     ...
# 306  2021-03-25 00:00:00  286.66
# 307  2021-03-26 00:00:00  291.22
# 308  2021-03-29 00:00:00   293.3
# 309  2021-03-30 00:00:00  293.25
# 310  2021-03-31 00:00:00  291.02
#
# [61 rows x 2 columns]

# %% [markdown]
# ## Plotting Current Prices of year 2020

# %%
# plot the time series
plt.plot(filtered_df['ds'],filtered_df['y'])
# plt.plot(df_sorted['ds'])
plt.xlabel('date')
plt.ylabel('price')
plt.title('Current Prices')
plt.show()

# %% [markdown]
# # Applying Prophet Model

# %%
# Create a Prophet model
model_Prophet = Prophet()

# Fit the model
model_Prophet.fit(filtered_df)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpi4ql81qb/owi24lhq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpi4ql81qb/364hqt7x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=24200', 'data', 'file=/tmp/tmpi4ql81qb/owi24lhq.json', 'init=/tmp/tmpi4ql81qb/364hqt7x.json', 'output', 'file=/tmp/tmpi4ql81qb/prophet_modelsc279fbf/prophet_model-20231127184042.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 18:40:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 18:40:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# ## Calculating working days in the period from 1st Jan to 31 Mar

# %%
weekend_days = [1,1,1,1,1,0,0]  # Saturday is 5, Sunday is 6

# %%
start_date = specific_date.date()
end_date = (specific_date + timedelta(89)).date()

# %%
print(start_date)
print(end_date)
# Out:
# 2020-12-31
# 2021-03-30

# %%
# Calculate working days by excluding weekends
# business_days = np.busday_count(start_date, end_date, weekmask=weekend_days)

business_days = len(df) - len(filtered_df)

print("Number of business days:", business_days) # -2 (to match the actual data of 61 days)
# Out:
# Number of business days: 61

# %%
# Including history to match data indices of current data
future = model_Prophet.make_future_dataframe(periods=business_days, include_history=True)
future.tail(business_days)
# Out:
#             ds
# 250 2020-12-31
# 251 2021-01-01
# 252 2021-01-02
# 253 2021-01-03
# 254 2021-01-04
# ..         ...
# 306 2021-02-25
# 307 2021-02-26
# 308 2021-02-27
# 309 2021-02-28
# 310 2021-03-01
#
# [61 rows x 1 columns]

# %% [markdown]
# ## Predicting future prices

# %%
forecast = model_Prophet.predict(future)
forecast[['ds', 'yhat']].tail(business_days)
# Out:
#             ds        yhat
# 250 2020-12-31  281.226864
# 251 2021-01-01  281.289835
# 252 2021-01-02  269.443118
# 253 2021-01-03  270.341749
# 254 2021-01-04  283.687795
# ..         ...         ...
# 306 2021-02-25  331.549875
# 307 2021-02-26  331.612846
# 308 2021-02-27  319.766130
# 309 2021-02-28  320.664760
# 310 2021-03-01  334.010806
#
# [61 rows x 2 columns]

# %% [markdown]
# ## Applying Forecasted Prices to the actual dates

# %%
df_future = df[df['Date'] > specific_date]
df_future['Date'] = pd.to_datetime(df_future['Date'])
# Out:
# <ipython-input-18-e01012146870>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_future['Date'] = pd.to_datetime(df_future['Date'])

# %%
df_future_copy = df_future.copy()

# %%
print(df_future_copy)
# Out:
#           Date   Price
# 250 2021-01-04     272
# 251 2021-01-05   275.2
# 252 2021-01-06  272.93
# 253 2021-01-08  283.64
# 254 2021-01-11  289.49
# ..         ...     ...
# 306 2021-03-25  286.66
# 307 2021-03-26  291.22
# 308 2021-03-29   293.3
# 309 2021-03-30  293.25
# 310 2021-03-31  291.02
#
# [61 rows x 2 columns]

# %% [markdown]
# ### Extracting Forecasted Yhat and applying it to the current dates

# %%
print(forecast['yhat'].tail(business_days))#.iloc[:-1])
# Out:
# 250    281.226864
# 251    281.289835
# 252    269.443118
# 253    270.341749
# 254    283.687795
#           ...
# 306    331.549875
# 307    331.612846
# 308    319.766130
# 309    320.664760
# 310    334.010806
# Name: yhat, Length: 61, dtype: float64

# %%
df_future_copy['Price'] = forecast['yhat']

# %%
df_future_copy.rename(columns={'Date': 'ds', 'Price': 'y'}, inplace=True)

# %%
print(df_future_copy)
# Out:
#             ds           y
# 250 2021-01-04  281.226864
# 251 2021-01-05  281.289835
# 252 2021-01-06  269.443118
# 253 2021-01-08  270.341749
# 254 2021-01-11  283.687795
# ..         ...         ...
# 306 2021-03-25  331.549875
# 307 2021-03-26  331.612846
# 308 2021-03-29  319.766130
# 309 2021-03-30  320.664760
# 310 2021-03-31  334.010806
#
# [61 rows x 2 columns]

# %% [markdown]
# ## Plotting Forecast

# %%
fig = model_Prophet.plot(forecast)
plt.title('Prophet Forecast')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
fig1 = model_Prophet.plot(forecast)

# %%
fig2 = model_Prophet.plot_components(forecast)

# %%
plot_plotly(model_Prophet, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c0661c26-1ad8-4dd0-b9f4-48b273e80afa" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0661c26-1ad8-4dd0-b9f4-48b273e80afa")) {                    Plotly.newPlot(                        "c0661c26-1ad8-4dd0-b9f4-48b273e80afa",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-17T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-10T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-25T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-02T00:00:00","2020-07-03T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28T00:00:00","2020-07-29T00:00:00","2020-07-30T00:00:00","2020-07-31T00:00:00","2020-08-03T00:00:00","2020-08-04T00:00:00","2020-08-05T00:00:00","2020-08-06T00:00:00","2020-08-07T00:00:00","2020-08-10T00:00:00","2020-08-11T00:00:00","2020-08-12T00:00:00","2020-08-13T00:00:00","2020-08-14T00:0 ...

# %% [markdown]
# ## Calculating Mean Absolute Percentage Error

# %%
y_true = df['Price'].tail(business_days).values

# %%
y_pred = df_future_copy['y'].values

# %%
print('predicted= ',y_pred,', Actual= ', y_true)
# Out:
# predicted=  [281.22686369 281.28983502 269.44311832 270.34174863 283.68779477
#  286.14989741 287.92502528 287.51724009 287.58021142 275.73349472
#  276.63212503 289.97817117 292.44027381 294.21540168 293.80761649
#  293.87058782 282.02387112 282.92250143 296.26854757 298.73065021
#  300.50577808 300.09799289 300.16096422 288.31424752 289.21287783
#  302.55892397 305.02102661 306.79615448 306.38836929 306.45134062
#  294.60462392 295.50325423 308.84930037 311.31140301 313.08653088
#  312.67874569 312.74171702 300.89500032 301.79363063 315.13967677
#  317.60177941 319.37690728 318.96912209 319.03209342 307.18537672
#  308.08400703 321.43005317 323.89215581 325.66728368 325.25949849
#  325.32246982 313.47575312 314.37438343 327.72042957 330.18253221
#  331.95766008 331.54987489 331.61284622 319.76612952 320.66475983
#  334.01080597] , Actual=  [272 275.2 272.93 283.64 289.49 289.99 283.78 284.79 276.9 279.79 278.19
#  279.8 274.4 268.25 265.3 269.34 265.5 265.96 258.11 263.8 263.15 263.53
#  270.11 271.7 275.2 268.98 265.9 264.7 266 271.81 270.9 270.9 266.99
#  271.34 270.51 273.71 271.9 270.71 270.17 273.58 279.1 278.01 274.75 277.5
#  285.79 282.24 286 284.93 292.74 292.33 283.35 279.25 285.47 288.65 282.6
#  285.79 286.66 291.22 293.3 293.25 291.02]

# %%
MAPE = mean_absolute_percentage_error(y_true, y_pred)

# %%
print('MAPE: %.3f' % MAPE)
# Out:
# MAPE: 0.103

# %% [markdown]
# ## Plotting Actual vs Forecasted for the 1st Quarter 2021

# %%
# plot expected vs actual
plt.plot(y_true, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %%
# plot the time series
plt.figure(figsize=(16, 8))
plt.plot(df['Date'],df['Price'], label= 'Actual')
plt.plot(df_future_copy['ds'], df_future_copy['y'], label='Predicted')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Current Prices')
plt.show()

# %% [markdown]
# ## Caclulating Bollinger Bands

# %%
window = 20  # Number of periods for moving average and standard deviation

# %%
df_future_copy = df_future_copy.reset_index(drop=True)

# %%
predictions_Bolinger = pd.concat([filtered_df[['ds','y']].tail(window).reset_index(drop=True),df_future_copy]).reset_index(drop=True)

# %%
predictions_Bolinger
# Out:
#            ds           y
# 0  2020-12-03      263.14
# 1  2020-12-04         270
# 2  2020-12-07      274.36
# 3  2020-12-08      275.49
# 4  2020-12-09      276.89
# ..        ...         ...
# 76 2021-03-25  331.549875
# 77 2021-03-26  331.612846
# 78 2021-03-29   319.76613
# 79 2021-03-30   320.66476
# 80 2021-03-31  334.010806
#
# [81 rows x 2 columns]

# %%
# Calculate Bollinger Bands
def calculate_bollinger_bands(db, window):
    db['SMA'] = db['y'].rolling(window=window).mean()
    db['STD'] = db['y'].rolling(window=window).std()
    db['High'] = db['SMA'] + (2 * db['STD'])
    db['Low'] = db['SMA'] - (2 * db['STD'])
    return db

window_size = 20

# Visualize the stock prices and Bollinger Bands
df_bol = calculate_bollinger_bands(predictions_Bolinger, window_size)

# %%
plt.figure(figsize=(16, 8))
plt.plot(df['Date'], df['Price'], label='Stock Price')
plt.plot(df_bol['ds'], df_bol['High'], label='Upper Bollinger Band')
plt.plot(df_bol['ds'], df_bol['Low'], label='Lower Bollinger Band')
plt.title('Stock Price and Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Buy/Hold/Sell Strategy

# %%
df_Test = df_Test.reset_index(drop=True)

# %%
df_bol = df_bol.tail(len(df_Test)).reset_index(drop=True)

# %%
predictions_Bolinger['Signal'] = ''

# %%
for i in range(len(df_Test)):
  if df_Test['Price'][i] < df_bol['Low'][i]:
    predictions_Bolinger['Signal'][i] = 'BUY'
  elif df_Test['Price'][i] > df_bol['Low'][i] and df_Test['Price'][i] < df_bol['High'][i]:
    predictions_Bolinger['Signal'][i] = 'HOLD'
  else: predictions_Bolinger['Signal'][i] = 'Sell'
# Out:
# <ipython-input-59-e11fab8ca5e2>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-59-e11fab8ca5e2>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-59-e11fab8ca5e2>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Visualize the results
plt.figure(figsize=(12, 6))
plt.plot(df_Test['Date'], df_Test['Price'], label='Actual Prices')
plt.plot(df_bol['ds'], df_bol['High'], label='Upper Bollinger Band')
plt.plot(df_bol['ds'], df_bol['Low'], label='Lower Bollinger Band')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# Display buy/sell signals
print(predictions_Bolinger['Signal'].value_counts())
# Out:
# BUY     45
#         20
# HOLD    14
# Sell     2
# Name: Signal, dtype: int64

# %% [markdown]
# # Applying LSTM Model

# %% [markdown]
# ### Importing DataFrame

# %%
# Filtering DF before the Q1 of second year
df_pd = df

print(df_pd)
# Out:
#                     Date   Price
# 0    2020-01-03 00:00:00     255
# 1    2020-01-06 00:00:00   253.9
# 2    2020-01-08 00:00:00  259.15
# 3    2020-01-09 00:00:00  257.99
# 4    2020-01-10 00:00:00  258.19
# ..                   ...     ...
# 306  2021-03-25 00:00:00  286.66
# 307  2021-03-26 00:00:00  291.22
# 308  2021-03-29 00:00:00   293.3
# 309  2021-03-30 00:00:00  293.25
# 310  2021-03-31 00:00:00  291.02
#
# [311 rows x 2 columns]

# %%
df_pd['Date'] = pd.to_datetime(df_pd['Date'])

# %%
df_pd['Price'] = df_pd['Price'].astype(float)

# %%
df_pd.dtypes
# Out:
# Date     datetime64[ns]
# Price           float64
# dtype: object

# %% [markdown]
# ## LSTM Data preparation

# %%
train = df_pd[df_pd['Date'] < specific_date]

# %%
print(train.shape)
# Out:
# (250, 2)

# %%
test = df_pd[df_pd['Date'] >= specific_date]

# %%
print(test.shape)
# Out:
# (61, 2)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df_pd['Price'].values.reshape(-1,1))
# df_scaled_test = scaler.fit_transform(test['Price'].values.reshape(-1,1))
# df_scaled = pd.DataFrame(df_scaled, columns=['Price'])
# df_scaled['Date'] = df['Date']

# %%
# Split the data into training and testing sets
train_size = int(len(train))
train_data, test_data = df_scaled[0:train_size], df_scaled[train_size:]

# Function to create sequences of data for training
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        X.append(dataset[i:(i + look_back), 0])
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 30  # Number of previous time steps to use for prediction
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# %%
# Reshape data for LSTM input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
X_train.shape, y_train.shape, X_test.shape,y_test.shape
# Out:
# ((220, 30, 1), (220,), (31, 30, 1), (31,))

# %% [markdown]
# ## Training LSTM Model

# %%
# Create and train the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 14ms/step - loss: 0.1145
# Epoch 2/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0218
# Epoch 3/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0139
# Epoch 4/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0114
# Epoch 5/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0099
# Epoch 6/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0084
# Epoch 7/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 8/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 9/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0062
# Epoch 10/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 11/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 12/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 13/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0063
# Epoch 14/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0056
# Epoch 15/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 16/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 17/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0052
# Epoch 18/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0050
# Epoch 19/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0049
# Epoch 20/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 21/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0048
# Epoch 22/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0046
# Epoch 23/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 24/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 25/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0046
# Epoch 26/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0043
# Epoch 27/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0042
# Epoch 28/100
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0044
# Epoch 29/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0042
# Epoch 30/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0043
# Epoch 31/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0041
# Epoch 32/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0042
# Epoch 33/100
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0044
# Epoch 34/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0039
# Epoch 35/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0037
# Epoch 36/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0036
# Epoch 37/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0036
# Epoch 38/100
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0037
# Epoch 39/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0037
# Epoch 40/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 41/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0035
# Epoch 42/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 43/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 44/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 45/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 46/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 47/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 48/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 49/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 50/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 51/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 52/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 53/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 54/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 55/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0029
# Epoch 56/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 57/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 58/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 59/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 60/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 61/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 62/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 63/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 64/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 65/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 66/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0025
# Epoch 67/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 68/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 69/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0028
# Epoch 70/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 71/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0025
# Epoch 72/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 73/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 74/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0025
# Epoch 75/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0026
# Epoch 76/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0025
# Epoch 77/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0023
# Epoch 78/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 79/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 80/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0022
# Epoch 81/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0022
# Epoch 82/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 83/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 84/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0024
# Epoch 85/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0023
# Epoch 86/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0021
# Epoch 87/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0021
# Epoch 88/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0022
# Epoch 89/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0023
# Epoch 90/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0024
# Epoch 91/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0024
# Epoch 92/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0021
# Epoch 93/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0023
# Epoch 94/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0022
# Epoch 95/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0024
# Epoch 96/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0024
# Epoch 97/100
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0020
# Epoch 98/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0020
# Epoch 99/100
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0021
# Epoch 100/100
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0020

# %%
# Make predictions
predict_X = model.predict(X_train[-1])
# test_predict = model.predict(X_test[-1])
# Out:
# 1/1 [==============================] - 0s 479ms/step

# %%
# Inverse transform predictions to original scale
predict_X = scaler.inverse_transform(predict_X)
# test_predict = scaler.inverse_transform([y_test])

# %%
print(predict_X)
# Out:
# [[196.77606]
#  [196.08218]
#  [195.84111]
#  [195.92049]
#  [198.0974 ]
#  [199.41685]
#  [198.89427]
#  [199.32434]
#  [198.75882]
#  [202.00734]
#  [202.96178]
#  [202.69115]
#  [204.71759]
#  [206.01549]
#  [206.3531 ]
#  [206.7721 ]
#  [208.36812]
#  [208.82997]
#  [207.6905 ]
#  [207.3149 ]
#  [207.20984]
#  [207.25487]
#  [204.76508]
#  [202.29468]
#  [202.36803]
#  [204.74727]
#  [204.51585]
#  [204.90762]
#  [206.11702]
#  [205.31201]]

# %%
# Create a copy of X_test to store the updated values
X_test_updated = X_train[-1].reshape(1, 30)
num_days_to_predict = len(test)
print(X_test_updated.shape)
# Out:
# (1, 30)

# %%
# Make predictions for the next 90 days and update X_test
predictions_list = []
for i in range(num_days_to_predict):
    # Make predictions for the current day
    predictions_new = model.predict(X_test_updated)
    #predictions = scaler.inverse_transform(predictions)

    # Append the predictions to X_test_updated for the next day
    X_test_updated = np.append(X_test_updated, predictions_new, axis=1)

    # Delete the first element from the array
    X_test_updated = X_test_updated[:, 1:]

    # Append the predictions to the list for plotting later
    predictions_list.append(predictions_new[0, 0])  # Assuming the prediction is a single value (e.g., the first column)

# reshape the predictions_list
predictions_list = np.array(predictions_list).reshape(-1, 1)
# apply the scaler.inverse_transform functio nto all the values in the predictions_list
predictions_list = scaler.inverse_transform(predictions_list)
# make a data frame from the predictions_list and add a column based on df['Date'][252:]
df_predictions = pd.DataFrame(predictions_list, columns=['Price'])
# Out:
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
# Filter the dates to keep only those from the year 2021
dates_2021 = test['Date']

# Reset the index to start from 0
dates_2021.reset_index(drop=True, inplace=True)

# Assign the filtered dates to the 'Date' column in 'df_predictions'
df_predictions['Date'] = dates_2021

df_predictions = df_predictions[['Date','Price']]

# %% [markdown]
# ## Plotting Actual vs Forecasted for the 1st Quarter 2021

# %%
# plot the predictions_list
plt.plot(df_pd['Date'], df_pd['Price'], label ='Actual Price')
plt.tick_params(axis='x', rotation=45)
plt.plot(df_predictions['Date'],df_predictions['Price'], label = 'Predicted Price')
plt.legend()
plt.show()

# %%
df_predictions_Bolinger = pd.concat([train[['Date','Price']].tail(window),df_predictions]).reset_index(drop=True)

# %%
df_predictions_Bolinger
# Out:
#          Date       Price
# 0  2020-12-03  263.140000
# 1  2020-12-04  270.000000
# 2  2020-12-07  274.360000
# 3  2020-12-08  275.490000
# 4  2020-12-09  276.890000
# ..        ...         ...
# 76 2021-03-25  203.349579
# 77 2021-03-26  203.776505
# 78 2021-03-29  204.230957
# 79 2021-03-30  204.708603
# 80 2021-03-31  205.204971
#
# [81 rows x 2 columns]

# %% [markdown]
# ## Calculating Bolinger for LSTM

# %%
# Calculate Bollinger Bands
def calculate_bollinger_bands(db, window):
    db['SMA'] = db['Price'].rolling(window=window).mean()
    db['STD'] = db['Price'].rolling(window=window).std()
    db['High'] = db['SMA'] + (2 * db['STD'])
    db['Low'] = db['SMA'] - (2 * db['STD'])
    return db

window_size = 20

# Visualize the stock prices and Bollinger Bands
df_b = calculate_bollinger_bands(df_predictions_Bolinger, window_size)

plt.figure(figsize=(16, 8))
plt.plot(df_pd['Date'], df_pd['Price'], label='Stock Price')
plt.plot(df_b['Date'], df_b['High'], label='Upper Bollinger Band')
plt.plot(df_b['Date'], df_b['Low'], label='Lower Bollinger Band')
plt.plot(df_predictions['Date'], df_predictions['Price'],label='Predcited')
plt.title('Stock Price and Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## Buy/Hold/Sell Strategy

# %%
test = test.reset_index(drop=True)

# %%
df_b = df_b.tail(len(test)).reset_index(drop=True)

# %%
df_b['Signal'] = ''

# %%
for i in range(len(test)):
  if test['Price'][i] < df_b['Low'][i]:
    df_b['Signal'][i] = 'BUY'
  elif test['Price'][i] > df_b['Low'][i] and test['Price'][i] < df_b['High'][i]:
    df_b['Signal'][i] = 'HOLD'
  else: df_b['Signal'][i] = 'Sell'
# Out:
# <ipython-input-87-eeb5633ad9d4>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-87-eeb5633ad9d4>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Visualize the results
plt.figure(figsize=(16, 8))
plt.plot(test['Date'], test['Price'], label='Stock Price')
plt.plot(df_b['Date'].tail(len(test)), df_b['High'].tail(len(test)), label='Upper Bollinger Band')
plt.plot(df_b['Date'].tail(len(test)), df_b['Low'].tail(len(test)), label='Lower Bollinger Band')
# plt.plot(df_predictions['Date'], df_predictions['Price'],label='Predcited')
plt.title('Stock Price and Bollinger Bands for the Q1 2021')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# Display buy/sell signals
print(df_b['Signal'].value_counts())
# Out:
# Sell    41
# HOLD    20
# Name: Signal, dtype: int64
